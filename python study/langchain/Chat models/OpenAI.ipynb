# %%
OPENAI_API_KEY = "sk-J5SBZ1hgnvUwJ4tfclSiET53pGaxP3m7mnIKfy3eoFXOGOEt"
OPENAI_BASE_URL = "https://api.chatanywhere.tech/v1/"

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    temperature = 0,
    model = "gpt-4o-mini",
    api_key = OPENAI_API_KEY,
    base_url = OPENAI_BASE_URL
)

# %% [markdown]
# ### Invocation

# %%
messages = [
    (
        "system",
        "you are a helpful assistant that translates English to Chinese. Translate the user sentence.",
    ),
    ("human","I love programming.")
]
ai_msg = llm.invoke(messages)
ai_msg
# Out:
# AIMessage(content='我喜欢编程。', response_metadata={'token_usage': {'completion_tokens': 5, 'prompt_tokens': 31, 'total_tokens': 36}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_611b667b19', 'finish_reason': 'stop', 'logprobs': None}, id='run-3b41a4c9-5412-44da-ad27-d5cdf5330d6c-0', usage_metadata={'input_tokens': 31, 'output_tokens': 5, 'total_tokens': 36})

# %% [markdown]
# ### Chaining

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages([
    (
        "system",
        "you are a helpful assistant that translates {input_language} to {output_language}. Translate the user sentence.",
    ),
    ("human","{input}")
])

chain = prompt | llm
chain.invoke({
    "input_language":"English",
    "output_language":"Chinese",
    "input":"I love programming."
})
# Out:
# AIMessage(content='我喜欢编程。', response_metadata={'token_usage': {'completion_tokens': 5, 'prompt_tokens': 31, 'total_tokens': 36}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_611b667b19', 'finish_reason': 'stop', 'logprobs': None}, id='run-e7543a32-a304-4b94-bdf8-eb88565eb13f-0', usage_metadata={'input_tokens': 31, 'output_tokens': 5, 'total_tokens': 36})

# %% [markdown]
# ### Tool calling

# %%
from langchain_core.pydantic_v1 import BaseModel,Field

class CetWeather(BaseModel):

    location:str = Field(...,description="The city and state,e.g. San Francisco, CA")

llm_with_tools = llm.bind_tools([CetWeather])

# %%
ai_msg = llm_with_tools.invoke(
    "What i the weather like in San Francisco"
)
ai_msg
# Out:
# AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_x5LlTYa8RBaDqzep6Hu0uF3z', 'function': {'arguments': '{"location":"San Francisco, CA"}', 'name': 'CetWeather'}, 'type': 'function', 'index': 0}]}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 58, 'total_tokens': 76}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_8b761cb050', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-22d4af4c-ad27-41cd-9fbf-e7ce9ae4677a-0', tool_calls=[{'name': 'CetWeather', 'args': {'location': 'San Francisco, CA'}, 'id': 'call_x5LlTYa8RBaDqzep6Hu0uF3z', 'type': 'tool_call'}], usage_metadata={'input_tokens': 58, 'output_tokens': 18, 'total_tokens': 76})

# %%
ai_msg.tool_calls
# Out:
# [{'name': 'CetWeather',
#   'args': {'location': 'San Francisco, CA'},
#   'id': 'call_x5LlTYa8RBaDqzep6Hu0uF3z',
#   'type': 'tool_call'}]

# %% [markdown]
# ### Fine-tuning

# %%
fine_tuned_model = ChatOpenAI(
    temperature=0,
    model_name="ft:gpt-3.5-turbo:langchain::7qTVM5AR",
    api_key=OPENAI_API_KEY,
    base_url=OPENAI_BASE_URL
)

fine_tuned_model(messages)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[19], line 8
#       1 fine_tuned_model = ChatOpenAI(
#       2     temperature=0,
#       3     model_name="ft:gpt-3.5-turbo:langchain::7qTVM5AR",
#       4     api_key=OPENAI_API_KEY,
#       5     base_url=OPENAI_BASE_URL
#       6 )
# ----> 8 fine_tuned_model(messages)
#
# File E:\python\python_study\venv\lib\site-packages\langchain_core\_api\deprecation.py:168, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     166     warned = True
#     167     emit_warning()
# --> 168 return wrapped(*args, **kwargs)
#
# File E:\python\python_study\venv\lib\site-packages\langchain_core\language_models\chat_models.py:946, in BaseChatModel.__call__(self, messages, stop, callbacks, **kwargs)
#     938 @deprecated("0.1.7", alternative="invoke", removal="0.3.0")
#     939 def __call__(
# ...
