# %%
# %pip install langchain -i https://pypi.tuna.tsinghua.edu.cn/simple
# %pip install langchain-community -i https://pypi.tuna.tsinghua.edu.cn/simple
# %pip install langchain-core -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: langchain in e:\python\python_study\venv\lib\site-packages (0.2.9)
# Requirement already satisfied: PyYAML>=5.3 in e:\python\python_study\venv\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in e:\python\python_study\venv\lib\site-packages (from langchain) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in e:\python\python_study\venv\lib\site-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in e:\python\python_study\venv\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.20 in e:\python\python_study\venv\lib\site-packages (from langchain) (0.2.21)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in e:\python\python_study\venv\lib\site-packages (from langchain) (0.2.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in e:\python\python_study\venv\lib\site-packages (from langchain) (0.1.90)
# Requirement already satisfied: numpy<2,>=1 in e:\python\python_study\venv\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in e:\python\python_study\venv\lib\site-packages (from langchain) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in e:\python\python_study\venv\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in e:\python\python_study\venv\lib\site-packages (from langchain) (8.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in e:\python\python_study\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in e:\python\python_study\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in e:\python\python_study\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in e:\python\python_study\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in e:\python\python_study\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in e:\python\python_study\venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.20->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in e:\python\python_study\venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.20->langchain) (24.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in e:\python\python_study\venv\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.6)
# Requirement already satisfied: annotated-types>=0.4.0 in e:\python\python_study\venv\lib\site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in e:\python\python_study\venv\lib\site-packages (from pydantic<3,>=1->langchain) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in e:\python\python_study\venv\lib\site-packages (from pydantic<3,>=1->langchain) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\python\python_study\venv\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in e:\python\python_study\venv\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\python\python_study\venv\lib\site-packages (from requests<3,>=2->langchain) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in e:\python\python_study\venv\lib\site-packages (from requests<3,>=2->langchain) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in e:\python\python_study\venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in e:\python\python_study\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.20->langchain) (3.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: langchain-community in e:\python\python_study\venv\lib\site-packages (0.2.7)
# Requirement already satisfied: PyYAML>=5.3 in e:\python\python_study\venv\lib\site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in e:\python\python_study\venv\lib\site-packages (from langchain-community) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in e:\python\python_study\venv\lib\site-packages (from langchain-community) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in e:\python\python_study\venv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.7 in e:\python\python_study\venv\lib\site-packages (from langchain-community) (0.2.9)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.12 in e:\python\python_study\venv\lib\site-packages (from langchain-community) (0.2.21)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in e:\python\python_study\venv\lib\site-packages (from langchain-community) (0.1.90)
# Requirement already satisfied: numpy<2,>=1 in e:\python\python_study\venv\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in e:\python\python_study\venv\lib\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in e:\python\python_study\venv\lib\site-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in e:\python\python_study\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in e:\python\python_study\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in e:\python\python_study\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in e:\python\python_study\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in e:\python\python_study\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in e:\python\python_study\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in e:\python\python_study\venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in e:\python\python_study\venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in e:\python\python_study\venv\lib\site-packages (from langchain<0.3.0,>=0.2.7->langchain-community) (0.2.2)
# Requirement already satisfied: pydantic<3,>=1 in e:\python\python_study\venv\lib\site-packages (from langchain<0.3.0,>=0.2.7->langchain-community) (2.8.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in e:\python\python_study\venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.12->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in e:\python\python_study\venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.12->langchain-community) (24.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in e:\python\python_study\venv\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (3.10.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\python\python_study\venv\lib\site-packages (from requests<3,>=2->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in e:\python\python_study\venv\lib\site-packages (from requests<3,>=2->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\python\python_study\venv\lib\site-packages (from requests<3,>=2->langchain-community) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in e:\python\python_study\venv\lib\site-packages (from requests<3,>=2->langchain-community) (2024.7.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in e:\python\python_study\venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in e:\python\python_study\venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in e:\python\python_study\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.12->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in e:\python\python_study\venv\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.7->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in e:\python\python_study\venv\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.7->langchain-community) (2.20.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in e:\python\python_study\venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: langchain-core in e:\python\python_study\venv\lib\site-packages (0.2.21)
# Requirement already satisfied: PyYAML>=5.3 in e:\python\python_study\venv\lib\site-packages (from langchain-core) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in e:\python\python_study\venv\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in e:\python\python_study\venv\lib\site-packages (from langchain-core) (0.1.90)
# Requirement already satisfied: packaging<25,>=23.2 in e:\python\python_study\venv\lib\site-packages (from langchain-core) (24.1)
# Requirement already satisfied: pydantic<3,>=1 in e:\python\python_study\venv\lib\site-packages (from langchain-core) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in e:\python\python_study\venv\lib\site-packages (from langchain-core) (8.5.0)
# Requirement already satisfied: jsonpointer>=1.9 in e:\python\python_study\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in e:\python\python_study\venv\lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core) (3.10.6)
# Requirement already satisfied: requests<3,>=2 in e:\python\python_study\venv\lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core) (2.32.3)
# Requirement already satisfied: annotated-types>=0.4.0 in e:\python\python_study\venv\lib\site-packages (from pydantic<3,>=1->langchain-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in e:\python\python_study\venv\lib\site-packages (from pydantic<3,>=1->langchain-core) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in e:\python\python_study\venv\lib\site-packages (from pydantic<3,>=1->langchain-core) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\python\python_study\venv\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in e:\python\python_study\venv\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\python\python_study\venv\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in e:\python\python_study\venv\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core) (2024.7.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in e:\python\python_study\venv\lib\site-packages (24.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in e:\python\python_study\venv\lib\site-packages (1.0.1)
# Note: you may need to restart the kernel to use updated packages.
