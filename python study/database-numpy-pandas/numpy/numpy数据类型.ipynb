# %%
# %pip install numpy
# Out:
# ...
#      -------------------------------------- 16.5/16.5 MB 646.9 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

dt = np.dtype(np.int32)
print(dt)
print(type(dt))
# Out:
# int32
# <class 'numpy.dtypes.Int32DType'>

# %%
import numpy as np

dt = np.dtype('<i8')
print(dt)
print(type(dt))
# Out:
# int64
# <class 'numpy.dtypes.Int64DType'>

# %%
import numpy as py
student = np.dtype([("name","S20")],[("age","i4")],[("score","f4")])
print(student)
print(type(student))
# Out:
# {'names': ['name'], 'formats': ['S20'], 'offsets': [0], 'itemsize': 20, 'aligned': True}
# <class 'numpy.dtypes.VoidDType'>
